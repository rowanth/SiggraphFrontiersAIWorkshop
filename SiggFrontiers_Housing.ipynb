# %% [markdown]
# <a href="https://colab.research.google.com/github/rowanth/SiggraphFrontiersAIWorkshop/blob/main/SiggFrontiers_Housing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # In this notebook,
# # we will try to load and look at some csv (comma separated values) data

# %% [markdown]
# Import all the needed python pacakges and libaries

# %%
# %tensorflow_version 2.x
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Read the data using pandas

# %%
#----------DATA READING 
filename = 'https://download.mlcc.google.com/mledu-datasets/california_housing_train.csv'
# read file
csv_data = pd.read_csv(filename, sep=',')

# %% [markdown]
# Data is read as a matrix, let's take a look at the shape of that matrix

# %%
print(csv_data.shape)
# Out:
# (17000, 9)

# %% [markdown]
# Take a look at the first five data points

# %%
print(csv_data.head())
# Out:
#    longitude  latitude  ...  median_income  median_house_value
# 0    -114.31     34.19  ...         1.4936             66900.0
# 1    -114.47     34.40  ...         1.8200             80100.0
# 2    -114.56     33.69  ...         1.6509             85700.0
# 3    -114.57     33.64  ...         3.1917             73400.0
# 4    -114.57     33.57  ...         1.9250             65500.0
#
# [5 rows x 9 columns]

# %% [markdown]
# Print the previous results transposed so we can see all the columns (features)

# %%
print(csv_data.head().transpose())
# Out:
#                              0         1           2           3          4
# longitude            -114.3100   -114.47   -114.5600   -114.5700   -114.570
# latitude               34.1900     34.40     33.6900     33.6400     33.570
# housing_median_age     15.0000     19.00     17.0000     14.0000     20.000
# total_rooms          5612.0000   7650.00    720.0000   1501.0000   1454.000
# total_bedrooms       1283.0000   1901.00    174.0000    337.0000    326.000
# population           1015.0000   1129.00    333.0000    515.0000    624.000
# households            472.0000    463.00    117.0000    226.0000    262.000
# median_income           1.4936      1.82      1.6509      3.1917      1.925
# median_house_value  66900.0000  80100.00  85700.0000  73400.0000  65500.000

# %% [markdown]
# Look at the basic data stats per column

# %%
print(csv_data.describe())
# Out:
#           longitude      latitude  ...  median_income  median_house_value
# count  17000.000000  17000.000000  ...   17000.000000        17000.000000
# mean    -119.562108     35.625225  ...       3.883578       207300.912353
# std        2.005166      2.137340  ...       1.908157       115983.764387
# min     -124.350000     32.540000  ...       0.499900        14999.000000
# 25%     -121.790000     33.930000  ...       2.566375       119400.000000
# 50%     -118.490000     34.250000  ...       3.544600       180400.000000
# 75%     -118.000000     37.720000  ...       4.767000       265000.000000
# max     -114.310000     41.950000  ...      15.000100       500001.000000
#
# [8 rows x 9 columns]

# %% [markdown]
# Take a look at just two features using pandas indexing by columns

# %%
print(csv_data[['latitude', 'longitude']])
# Out:
#        latitude  longitude
# 0         34.19    -114.31
# 1         34.40    -114.47
# 2         33.69    -114.56
# 3         33.64    -114.57
# 4         33.57    -114.57
# ...         ...        ...
# 16995     40.58    -124.26
# 16996     40.69    -124.27
# 16997     41.84    -124.30
# 16998     41.80    -124.30
# 16999     40.54    -124.35
#
# [17000 rows x 2 columns]

# %% [markdown]
# Do a scatter plot of 2 of the columns (latitute on the x-axis, longitude on the y-axis) and use 'total_bedrooms' as the size of the dots.

# %%
sns.relplot(x='latitude', y='longitude', size='total_bedrooms', alpha=0.5, palette='muted', data=csv_data)

# %% [markdown]
# Take the first 1000 data points (using the head(xxxx) function) and plot 5 of features against each other.

# %%
sns.pairplot(csv_data.head(1000)[['longitude', 'latitude', 'total_bedrooms', 'median_house_value', 'population']])

# %% [markdown]
# why is the map messed up?

# %%
sns.pairplot(csv_data.sample(n=1000)[['longitude', 'latitude', 'total_bedrooms', 'median_house_value', 'population']])
